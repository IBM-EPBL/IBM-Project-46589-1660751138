# %%
# !unzip '/content/sample_data/DigitalDataset.zip'
# Out:
# Archive:  /content/sample_data/DigitalDataset.zip
#    creating: Dataset/Bird/
#    creating: Dataset/Bird/Great Indian Bustard Bird/
#   inflating: Dataset/Bird/Great Indian Bustard Bird/download (1).jpg
#   inflating: Dataset/Bird/Great Indian Bustard Bird/download (10).jpg
#   inflating: Dataset/Bird/Great Indian Bustard Bird/download (11).jpg
#   inflating: Dataset/Bird/Great Indian Bustard Bird/download (2).jpg
#   inflating: Dataset/Bird/Great Indian Bustard Bird/download (3).jpg
#   inflating: Dataset/Bird/Great Indian Bustard Bird/download (4).jpg
#   inflating: Dataset/Bird/Great Indian Bustard Bird/download (5).jpg
#   inflating: Dataset/Bird/Great Indian Bustard Bird/download (6).jpg
#   inflating: Dataset/Bird/Great Indian Bustard Bird/download (7).jpg
#   inflating: Dataset/Bird/Great Indian Bustard Bird/download (8).jpg
#   inflating: Dataset/Bird/Great Indian Bustard Bird/download (9).jpg
#   inflating: Dataset/Bird/Great Indian Bustard Bird/download.jpg
# ...

# %% [markdown]
# **Importing** **Libraries**

# %%
from keras.preprocessing.image import ImageDataGenerator
import cv2
from os import listdir
import time

# %% [markdown]
#  **Data Augment function**

# %%
def data_augment(file_dir, n_generated_samples, save_to_dir):
    data_gen = ImageDataGenerator(rotation_range=30, 
                                  width_shift_range=0.1,
                                  height_shift_range=0.15, 
                                  shear_range=0.25, 
                                  zoom_range = 0.2,
                                  horizontal_flip=True, 
                                  vertical_flip=False, 
                                  fill_mode='nearest',
                                  brightness_range=(0.5,1.2)
                                 )
    for filename in listdir(file_dir):
        image = cv2.imread(file_dir + '/' + filename)
        image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
        image = image.reshape((1,)+image.shape)
        save_prefix = 'aug_' + filename[:-4]    
        i=0
        for batch in data_gen.flow(x=image, batch_size=1, save_to_dir=save_to_dir,
                                   save_prefix=save_prefix, save_format='jpg'):
            i += 1
            if i > n_generated_samples:
                break

# %%
augmented_data_path = '/content/Augment_data'
data_augment(file_dir='/content/Dataset/Bird/Great Indian Bustard Bird', n_generated_samples=20, save_to_dir=augmented_data_path+'/GIB_AUG')
data_augment(file_dir='/content/Dataset/Bird/Spoon Billed Sandpiper Bird', n_generated_samples=20, save_to_dir=augmented_data_path+'/SPS_AUG')
data_augment(file_dir='/content/Dataset/Flower/Corpse Flower', n_generated_samples=20, save_to_dir=augmented_data_path+'/Corpse_AUG')
data_augment(file_dir='/content/Dataset/Flower/Lady Slipper Orchid Flower', n_generated_samples=20, save_to_dir=augmented_data_path+'/LS_Orchid_AUG')
data_augment(file_dir='/content/Dataset/Mammal/Pangolin Mammal', n_generated_samples=20, save_to_dir=augmented_data_path+'/LS_Pangolin_AUG')
data_augment(file_dir='/content/Dataset/Mammal/Senenca White Deer Mammal', n_generated_samples=20, save_to_dir=augmented_data_path+'/SW_Deer_AUG')

# %%
# !zip -r /content/Augment_data.zip /content/Augment_data
# Out:
#   adding: content/Augment_data/ (stored 0%)
#   adding: content/Augment_data/GIB_AUG/ (stored 0%)
#   adding: content/Augment_data/GIB_AUG/aug_download (2)_0_6629.jpg (deflated 2%)
#   adding: content/Augment_data/GIB_AUG/aug_download (6)_0_3500.jpg (deflated 2%)
#   adding: content/Augment_data/GIB_AUG/aug_images (1)_0_695.jpg (deflated 2%)
#   adding: content/Augment_data/GIB_AUG/aug_images (7)_0_6849.jpg (deflated 3%)
#   adding: content/Augment_data/GIB_AUG/aug_download (5)_0_3065.jpg (deflated 1%)
#   adding: content/Augment_data/GIB_AUG/aug_download (9)_0_5970.jpg (deflated 3%)
#   adding: content/Augment_data/GIB_AUG/aug_download (7)_0_9545.jpg (deflated 2%)
#   adding: content/Augment_data/GIB_AUG/aug_download (10)_0_9609.jpg (deflated 3%)
#   adding: content/Augment_data/GIB_AUG/aug_download (6)_0_2250.jpg (deflated 2%)
#   adding: content/Augment_data/GIB_AUG/aug_download (10)_0_2022.jpg (deflated 3%)
# ...

# %%
from google.colab import files
files.download("/content/Augment_data.zip")
